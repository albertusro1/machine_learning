# %%
# import all the necessary library
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split

# load datasets into variable, split the data(atribute) and the target(label) to different variables
iris = datasets.load_iris()
x = iris.data
y = iris.target

# call the train_test_split with 3 parameters : atribute, label(target), test_size and return 4 parameters
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# print test set's length
len(x_test)
# Out:
# 30
